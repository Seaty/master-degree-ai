# %% [markdown]
# # Ans Week03 assignment 01

# %%
import IPython
import sys
import os
from openai import OpenAI
from dotenv import load_dotenv


def clean_notebook():
    IPython.display.clear_output(wait=True)
    print("Notebook cleaned.")

# Clean up the notebook
clean_notebook()


# Load environment variables
print(load_dotenv())

openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
model_name = "gpt-4.1-mini"
# Out:
# Notebook cleaned.
# True

# %%
Context = """
## ประวัติ "โดราเอมอน": การ์ตูนอมตะขวัญใจคนทั่วโลก

"โดราเอมอน" (Doraemon) การ์ตูนญี่ปุ่นที่ครองใจเด็กและผู้ใหญ่ทั่วโลกมายาวนานกว่าครึ่งศตวรรษ คือเรื่องราวของหุ่นยนต์แมวสีฟ้าจากโลกอนาคตที่เดินทางย้อนเวลากลับมาเพื่อช่วยเหลือเด็กชายผู้ไม่เอาไหนอย่าง "โนบิ โนบิตะ" ด้วย "ของวิเศษ" จากกระเป๋าสี่มิติ เรื่องราวอันเปี่ยมไปด้วยจินตนาการ มิตรภาพ และเสียงหัวเราะนี้เริ่มต้นขึ้นจากปลายปากกาของนักเขียนการ์ตูนนามปากกา "ฟูจิโกะ เอฟ ฟูจิโอะ" และได้เดินทางผ่านยุคสมัยจนกลายเป็นหนึ่งในสัญลักษณ์ทางวัฒนธรรมที่สำคัญของประเทศญี่ปุ่น

### จุดกำเนิดจากปลายปากกา: ฉบับมังงะ

การเดินทางของโดราเอมอนเริ่มต้นขึ้นในเดือนธันวาคม ปี พ.ศ. 2512 (ค.ศ. 1969) ในรูปแบบของหนังสือการ์ตูน (มังงะ) โดยได้รับการตีพิมพ์พร้อมกันในนิตยสารสำหรับเด็ก 6 ฉบับของสำนักพิมพ์โชงะกุกัง ผลงานการสร้างสรรค์ของ **ฟูจิโกะ เอฟ ฟูจิโอะ** (นามปากกาของ ฮิโรชิ ฟูจิโมโตะ) ซึ่งในขณะนั้นทำงานร่วมกับ โมโตโอะ อาบิโกะ ในนามปากก "ฟูจิโกะ ฟูจิโอะ"

เนื้อเรื่องหลักเล่าถึง "โดราเอมอน" หุ่นยนต์แมวพี่เลี้ยงเด็กจากศตวรรษที่ 22 ที่ถูกส่งมาโดย "เซวาชิ" เหลนของโนบิตะ เพื่อเปลี่ยนแปลงอนาคตอันเลวร้ายของตระกูลโนบิ ซึ่งมีสาเหตุมาจากความขี้เกียจและโชคร้ายของโนบิตะในวัยเด็ก โดราเอมอนจึงต้องใช้ของวิเศษจากกระเป๋าหน้าท้องเพื่อคอยช่วยเหลือและสั่งสอนโนบิตะให้เติบโตเป็นผู้ใหญ่ที่ดีขึ้น

มังงะโดราเอมอนได้รับความนิยมอย่างรวดเร็ว ด้วยลายเส้นที่เรียบง่ายแต่เปี่ยมไปด้วยเอกลักษณ์ เนื้อเรื่องที่สนุกสนาน สอดแทรกแง่คิดสอนใจ และจินตนาการอันไร้ขีดจำกัดของของวิเศษต่างๆ ทำให้โดราเอมอนกลายเป็นเพื่อนรักในจินตนาการของเด็กๆ ทั่วญี่ปุ่น

### ก้าวสู่จอแก้ว: ฉบับแอนิเมชัน

ความสำเร็จของฉบับมังงะได้ปูทางให้โดราเอมอนโลดแล่นบนจอโทรทัศน์ในรูปแบบของแอนิเมชัน (อะนิเมะ) ซึ่งมีการสร้างออกมาหลายเวอร์ชันด้วยกัน:

* **ซีรีส์ปี พ.ศ. 2516 (ค.ศ. 1973):** ออกอากาศทางสถานีโทรทัศน์นิปปอนทีวี เป็นซีรีส์ชุดแรกสุด แต่ไม่ได้รับความนิยมมากนักและมีจำนวนตอนไม่มากนัก
* **ซีรีส์ปี พ.ศ. 2522 - 2548 (ค.ศ. 1979 - 2005):** ออกอากาศทางสถานีโทรทัศน์ทีวีอาซาฮี ซีรีส์ชุดนี้คือเวอร์ชันที่สร้างชื่อเสียงและทำให้โดราเอมอนเป็นที่รู้จักไปทั่วโลก ด้วยจำนวนตอนกว่า 1,787 ตอน และลายเส้นที่กลายเป็นภาพจำของแฟนๆ ทั่วโลก รวมถึงในประเทศไทย
* **ซีรีส์ปี พ.ศ. 2548 - ปัจจุบัน (ค.ศ. 2005 - ปัจจุบัน):** เป็นการสร้างใหม่ทั้งหมด (Reboot) โดยมีการปรับเปลี่ยนทีมงานผู้สร้าง นักพากย์ และปรับปรุงลายเส้นให้ทันสมัยยิ่งขึ้น แต่ยังคงเค้าโครงเรื่องและเสน่ห์ของตัวละครไว้อย่างครบถ้วน ซีรีส์ชุดนี้ยังคงออกอากาศต่อเนื่องมาจนถึงปัจจุบัน

### การผจญภัยบนจอเงิน: โดราเอมอน เดอะมูฟวี่

นอกเหนือจากแอนิเมชันซีรีส์ทางโทรทัศน์แล้ว "โดราเอมอน เดอะมูฟวี่" หรือภาพยนตร์จอใหญ่ ถือเป็นอีกหนึ่งหมุดหมายสำคัญที่แฟนๆ ต่างรอคอยในทุกๆ ปี ภาพยนตร์เรื่องแรกคือ **"ไดโนเสาร์ของโนบิตะ" (Nobita's Dinosaur)** ออกฉายในปี พ.ศ. 2523 (ค.ศ. 1980) และประสบความสำเร็จอย่างงดงาม

จากนั้นเป็นต้นมา โดราเอมอน เดอะมูฟวี่ ก็ได้ออกฉายอย่างต่อเนื่องเกือบทุกปี โดยมีเนื้อหาเป็นการผจญภัยในดินแดนที่แปลกใหม่และยิ่งใหญ่กว่าในฉบับทีวีซีรีส์ เช่น การท่องไปในอวกาศ ดำดิ่งสู่ใต้ทะเลลึก หรือย้อนกลับไปในยุคประวัติศาสตร์ต่างๆ ภาพยนตร์เหล่านี้ไม่เพียงแต่ให้ความบันเทิง แต่ยังสอดแทรกประเด็นเกี่ยวกับมิตรภาพ ความกล้าหาญ และการอนุรักษ์สิ่งแวดล้อมอีกด้วย

### โดราเอมอนในประเทศไทย

สำหรับประเทศไทย โดราเอมอนได้เข้ามาเป็นส่วนหนึ่งของวัฒนธรรมสมัยนิยมและเป็นเพื่อนในวัยเด็กของคนไทยจำนวนมาก โดยเริ่มออกอากาศครั้งแรกทางสถานีโทรทัศน์ช่อง 9 อ.ส.ม.ท. (ปัจจุบันคือ ช่อง 9 MCOT HD) เมื่อวันที่ **5 กันยายน พ.ศ. 2525 (ค.ศ. 1982)** และได้รับความนิยมอย่างล้นหลามจนมีการฉายซ้ำและนำตอนใหม่ๆ มาออกอากาศอย่างต่อเนื่อง

ในส่วนของหนังสือการ์ตูน ปัจจุบัน **สำนักพิมพ์เนชั่น เอ็ดดูเทนเมนท์** เป็นผู้ได้รับลิขสิทธิ์ในการจัดพิมพ์อย่างเป็นทางการในประเทศไทย

ความผูกพันระหว่างโดราเอมอนกับแฟนๆ ชาวไทยยังคงเด่นชัดผ่านกิจกรรมต่างๆ เช่น นิทรรศการ **"100% DORAEMON&FRIENDS"** ที่จัดขึ้นในปี พ.ศ. 2568 และล่าสุดในปีเดียวกันนี้ ยังมีแอนิเมชันตอนพิเศษที่โดราเอมอนและโนบิตะเดินทางมาเที่ยวประเทศไทย โดยมีฉากหลังเป็นสถานที่ท่องเที่ยวชื่อดังอย่างอยุธยาและตลาดน้ำดำเนินสะดวก ซึ่งสร้างความประทับใจให้แก่แฟนๆ ชาวไทยเป็นอย่างมาก

### ความนิยมทั่วโลกและมรดกที่ส่งต่อ

โดราเอมอนไม่ได้เป็นที่รักแค่ในญี่ปุ่นและไทยเท่านั้น แต่ยังโด่งดังไปทั่วเอเชียและอีกหลายประเทศทั่วโลก ได้รับการแปลไปแล้วกว่า 30 ภาษา และได้รับการแต่งตั้งให้เป็น "ทูตวัฒนธรรมแอนิเมชัน" คนแรกของญี่ปุ่นในปี พ.ศ. 2551 (ค.ศ. 2008) ซึ่งเป็นเครื่องยืนยันถึงอิทธิพลในระดับนานาชาติได้เป็นอย่างดี

เรื่องราวของ "โดราเอมอน" ได้พิสูจน์แล้วว่าจินตนาการและมิตรภาพคือภาษาสากลที่สามารถก้าวข้ามผ่านพรมแดนและกาลเวลา จากจุดเริ่มต้นในหน้ากระดาษเมื่อ 50 กว่าปีก่อน สู่การเป็นไอคอนทางวัฒนธรรมที่ยังคงมอบความสุข เสียงหัวเราะ และแรงบันดาลใจให้กับผู้คนทั่วโลกจวบจนทุกวันนี้
"""

# %%
questions_list = [
    # หมวด: จุดกำเนิดและมังงะ
    "1. จากบทความ การ์ตูน 'โดราเอมอน' มีจุดเริ่มต้นครั้งแรกในรูปแบบใด และใครคือผู้สร้างสรรค์ผลงานชิ้นนี้?",
    "2. แล้วผลงานในรูปแบบมังงะที่ว่านั้น เริ่มตีพิมพ์ครั้งแรกสุดในปี พ.ศ. ใด ตามที่บทความระบุ?",
    "3. ในปี พ.ศ. 2512 ที่คุณกล่าวถึงนั้น มังงะเรื่องนี้ได้รับการตีพิมพ์ในลักษณะพิเศษอย่างไร?",
    "4. การตีพิมพ์ในนิตยสารสำหรับเด็กทั้ง 6 ฉบับที่ว่านั้น เป็นของสำนักพิมพ์ใด?",
    "5. จากเนื้อเรื่องที่กล่าวถึงในบทความ ตัวละครหลักที่เป็นหุ่นยนต์แมวสีฟ้ามีชื่อว่าอะไร และเขามาจากยุคสมัยใด?",
    "6. โดราเอมอนที่มาจากศตวรรษที่ 22 นั้น มีภารกิจสำคัญอะไรในการเดินทางย้อนเวลากลับมา?",
    "7. การที่เขาต้องมาช่วยเหลือ 'โนบิ โนบิตะ' นั้น มีสาเหตุเบื้องหลังมาจากอะไร และใครคือผู้ที่ส่งเขามา?",
    "8. แล้ว 'เซวาชิ' ผู้เป็นเหลนของโนบิตะ ต้องการเปลี่ยนแปลงอนาคตเรื่องใดของตระกูลโนบิ?",
    "9. ในการปฏิบัติภารกิจเพื่อช่วยเหลือโนบิตะที่ว่านั้น โดราเอมอนใช้สิ่งใดเป็นเครื่องมือหลัก?",
    
    # หมวด: แอนิเมชันและภาพยนตร์
    "10. ความสำเร็จอย่างสูงของฉบับมังงะ ได้นำไปสู่การสร้างผลงานในรูปแบบใดต่อมา?",
    "11. แอนิเมชันทางโทรทัศน์ที่ว่านั้น มีการสร้างครั้งแรกสุดในปี พ.ศ. ใด และออกอากาศทางสถานีใด?",
    "12. ซีรีส์แรกสุดในปี 2516 ที่คุณกล่าวถึง ได้รับความนิยมมากน้อยเพียงใดตามข้อมูลในบทความ?",
    "13. หลังจากซีรีส์ชุดแรกที่ไม่ค่อยประสบความสำเร็จ ซีรีส์ชุดต่อมาที่ทำให้โดราเอมอนโด่งดังไปทั่วโลก เริ่มออกอากาศในปี พ.ศ. ใด?",
    "14. ซีรีส์ที่เริ่มฉายในปี พ.ศ. 2522 และกลายเป็นภาพจำของแฟนๆ ทั่วโลกนั้น ออกอากาศยาวนานไปจนถึงปี พ.ศ. ใด?",
    "15. หลังจากสิ้นสุดยุคของซีรีส์ในปี 2548 ในปีถัดมาได้มีการเปลี่ยนแปลงครั้งสำคัญอะไรเกิดขึ้นกับแอนิเมชันโดราเอมอน?",
    "16. การสร้างใหม่ในปี 2548 ที่ว่านั้น มีการปรับเปลี่ยนในด้านใดบ้างที่เด่นชัดตามที่บทความกล่าวไว้?",
    "17. นอกเหนือจากซีรีส์ทางโทรทัศน์แล้ว โดราเอมอนยังมีผลงานในรูปแบบภาพยนตร์จอใหญ่ด้วยใช่หรือไม่? ถ้าใช่ ภาพยนตร์เรื่องแรกมีชื่อว่าอะไร?",
    "18. ภาพยนตร์เรื่อง 'ไดโนเสาร์ของโนบิตะ' ที่คุณเพิ่งกล่าวถึงนั้น ออกฉายในปี พ.ศ. ใด?",
    "19. เนื้อหาของภาพยนตร์เดอะมูฟวี่เหล่านี้ มักจะมีความแตกต่างจากฉบับทีวีซีรีส์ในลักษณะใด?",

    # หมวด: โดราเอมอนในประเทศไทยและทั่วโลก
    "20. เมื่อพูดถึงความนิยมในต่างประเทศ โดยเฉพาะในประเทศไทย การ์ตูนเรื่องนี้เริ่มออกอากาศครั้งแรกเมื่อใด และผ่านทางสถานีใด?",
    "21. สถานีโทรทัศน์ช่อง 9 อ.ส.ม.ท. ที่นำโดราเอมอนมาฉายในปี 2525 นั้น ปัจจุบันคือช่องอะไร?",
    "22. แล้วในส่วนของฉบับหนังสือการ์ตูนในประเทศไทย ปัจจุบันสำนักพิมพ์ใดคือผู้ได้รับลิขสิทธิ์ในการจัดพิมพ์อย่างเป็นทางการ?",
    "23. นอกจากผลงานการ์ตูนแล้ว บทความได้กล่าวถึงกิจกรรมล่าสุดอะไรในไทยที่แสดงถึงความผูกพันกับแฟนๆ ?",
    "24. นอกเหนือจากนิทรรศการ '100% DORAEMON&FRIENDS' แล้ว ยังมีผลงานแอนิเมชันตอนพิเศษอะไรอีกที่สร้างขึ้นเพื่อแฟนชาวไทยโดยเฉพาะ?",
    "25. ในตอนพิเศษที่โดราเอมอนและโนบิตะมาเที่ยวประเทศไทยนั้น พวกเขาได้เดินทางไปยังสถานที่ท่องเที่ยวสำคัญแห่งใดบ้าง?",
    "26. ความนิยมในระดับนานาชาติของโดราเอมอน ทำให้ได้รับการแต่งตั้งให้ดำรงตำแหน่งสำคัญอะไรจากรัฐบาลญี่ปุ่น?",
    "27. การได้รับตำแหน่ง 'ทูตวัฒนธรรมแอนิเมชัน' คนแรกที่ว่านั้น เกิดขึ้นในปี พ.ศ. ใด?",

    # หมวด: สรุปและเชื่อมโยง
    "28. จากที่เราคุยกันมาทั้งหมด ตั้งแต่จุดกำเนิดในรูปแบบมังงะจนถึงการเป็นทูตวัฒนธรรม คุณคิดว่าแอนิเมชันซีรีส์ในยุคใด (พ.ศ.) ที่บทความระบุว่ามีบทบาทสำคัญที่สุดในการสร้างชื่อเสียงระดับโลกให้กับโดราเอมอน?",
    "29. เมื่อพิจารณาจากแอนิเมะยุคที่โด่งดังที่สุด (พ.ศ. 2522-2548) และภาพยนตร์เรื่องแรก (พ.ศ. 2523) เหตุการณ์ใดเกิดขึ้นก่อนกัน?",
    "30. สุดท้ายแล้ว จากการเดินทางอันยาวนานที่เริ่มต้นจากปลายปากกาของ 'ฟูจิโกะ เอฟ ฟูจิโอะ' บทความได้สรุปว่าโดราเอมอนได้มอบมรดกที่สำคัญอะไรให้กับผู้คนทั่วโลก?"
]

# %%
chat_history = []

def get_dict_prompt(role ,content):
    return  {"role": role, "content": content}


def get_chat_completion(messages):
    response = openai_client.chat.completions.create(
        model=model_name, # You can choose other models like "gpt-4"
        messages=messages,
        temperature=0.7
    )
    assistant_reply = response.choices[0].message.content
    return assistant_reply

def answer(question):
    prompt = f"""Please answer the following question:

    Question:

    ```{question}```

    Use the following context to find the answer:

    ```{Context}```
    """

    chat_history.append(get_dict_prompt("user",prompt))
    completion = get_chat_completion(chat_history)

    if completion == None :
      chat_history.append(get_dict_prompt("assistant",completion))
      print("Can't answer")
      return "Can't answer"
    else :
      chat_history.append(get_dict_prompt("assistant",completion))
      print(completion)
      return completion

# %%
for question in questions_list:
    print(f"Question: {question}")
    IPython.display.Markdown(answer(question))
    print("\n" + "="*50 + "\n")
# Out:
# Question: 1. จากบทความ การ์ตูน 'โดราเอมอน' มีจุดเริ่มต้นครั้งแรกในรูปแบบใด และใครคือผู้สร้างสรรค์ผลงานชิ้นนี้?
# จากบทความ ข้อความที่เกี่ยวข้องกับคำถามคือ:
#
# - โดราเอมอนมีจุดเริ่มต้นครั้งแรกในเดือนธันวาคม ปี พ.ศ. 2512 (ค.ศ. 1969) ในรูปแบบของหนังสือการ์ตูน (มังงะ)
# - ผลงานสร้างสรรค์โดย "ฟูจิโกะ เอฟ ฟูจิโอะ" (นามปากกาของ ฮิโรชิ ฟูจิโมโตะ) ซึ่งร่วมงานกับ โมโตโอะ อาบิโกะ ในนามปากกา "ฟูจิโกะ ฟูจิโอะ"
#
# **ดังนั้นคำตอบคือ:**
#
# โดราเอมอนมีจุดเริ่มต้นครั้งแรกในรูปแบบของหนังสือการ์ตูน (มังงะ) โดยผู้สร้างสรรค์ผลงานชิ้นนี้คือ ฟูจิโกะ เอฟ ฟูจิโอะ (นามปากกาของ ฮิโรชิ ฟูจิโมโตะ และ โมโตโอะ อาบิโกะ)
#
# ==================================================
#
# Question: 2. แล้วผลงานในรูปแบบมังงะที่ว่านั้น เริ่มตีพิมพ์ครั้งแรกสุดในปี พ.ศ. ใด ตามที่บทความระบุ?
# จากบทความ ระบุว่า มังงะโดราเอมอนเริ่มตีพิมพ์ครั้งแรกในเดือนธันวาคม ปี พ.ศ. 2512 (ค.ศ. 1969)
#
# **คำตอบ:**
# ผลงานในรูปแบบมังงะของโดราเอมอนเริ่มตีพิมพ์ครั้งแรกในปี พ.ศ. 2512
#
# ==================================================
#
# Question: 3. ในปี พ.ศ. 2512 ที่คุณกล่าวถึงนั้น มังงะเรื่องนี้ได้รับการตีพิมพ์ในลักษณะพิเศษอย่างไร?
# จากบทความ ระบุไว้ว่าในปี พ.ศ. 2512 มังงะโดราเอมอนได้รับการตีพิมพ์พร้อมกันในนิตยสารสำหรับเด็ก 6 ฉบับของสำนักพิมพ์โชงะกุกัง
#
# **คำตอบ:**
# ในปี พ.ศ. 2512 มังงะโดราเอมอนได้รับการตีพิมพ์ในลักษณะพิเศษคือ การตีพิมพ์พร้อมกันในนิตยสารสำหรับเด็ก 6 ฉบับของสำนักพิมพ์โชงะกุกัง
#
# ==================================================
#
# Question: 4. การตีพิมพ์ในนิตยสารสำหรับเด็กทั้ง 6 ฉบับที่ว่านั้น เป็นของสำนักพิมพ์ใด?
# จากบทความระบุว่า การตีพิมพ์มังงะโดราเอมอนในนิตยสารสำหรับเด็ก 6 ฉบับนั้น เป็นของ **สำนักพิมพ์โชงะกุกัง**
#
# **คำตอบ:**
# นิตยสารสำหรับเด็กทั้ง 6 ฉบับที่ตีพิมพ์มังงะโดราเอมอนในปี พ.ศ. 2512 เป็นของสำนักพิมพ์โชงะกุกัง
#
# ==================================================
#
# Question: 5. จากเนื้อเรื่องที่กล่าวถึงในบทความ ตัวละครหลักที่เป็นหุ่นยนต์แมวสีฟ้ามีชื่อว่าอะไร และเขามาจากยุคสมัยใด?
# จากบทความ ระบุว่า ตัวละครหลักที่เป็นหุ่นยนต์แมวสีฟ้ามีชื่อว่า **โดราเอมอน** และเขามาจากยุคสมัย **ศตวรรษที่ 22** (โลกอนาคต)
#
# **คำตอบ:**
# ตัวละครหลักคือ "โดราเอมอน" หุ่นยนต์แมวสีฟ้าที่มาจากยุคศตวรรษที่ 22
#
# ==================================================
#
# Question: 6. โดราเอมอนที่มาจากศตวรรษที่ 22 นั้น มีภารกิจสำคัญอะไรในการเดินทางย้อนเวลากลับมา?
# จากบทความ ระบุว่า โดราเอมอนที่มาจากศตวรรษที่ 22 มีภารกิจสำคัญในการเดินทางย้อนเวลากลับมาเพื่อช่วยเหลือเด็กชายชื่อ "โนบิ โนบิตะ" ซึ่งเป็นเหลนของเขาในอนาคต โดยมีเป้าหมายเพื่อเปลี่ยนแปลงอนาคตอันเลวร้ายของตระกูลโนบิ ที่เกิดจากความขี้เกียจและโชคร้ายของโนบิตะในวัยเด็ก โดราเอมอนจึงใช้ของวิเศษจากกระเป๋าหน้าท้องช่วยเหลือและสั่งสอนโนบิตะให้เติบโตเป็นผู้ใหญ่ที่ดีขึ้น
#
# **คำตอบ:**
# โดราเอมอนมีภารกิจสำคัญคือ การเดินทางย้อนเวลากลับมาเพื่อช่วยเหลือและสั่งสอนเด็กชายโนบิ โนบิตะ ให้เติบโตเป็นผู้ใหญ่ที่ดีขึ้น และเปลี่ยนแปลงอนาคตอันเลวร้ายของตระกูลโนบิให้ดีขึ้น
#
# ==================================================
#
# Question: 7. การที่เขาต้องมาช่วยเหลือ 'โนบิ โนบิตะ' นั้น มีสาเหตุเบื้องหลังมาจากอะไร และใครคือผู้ที่ส่งเขามา?
# จากบทความ ระบุว่า
#
# - สาเหตุเบื้องหลังที่โดราเอมอนต้องมาช่วยเหลือ "โนบิ โนบิตะ" คือ อนาคตอันเลวร้ายของตระกูลโนบิ ซึ่งเกิดจากความขี้เกียจและโชคร้ายของโนบิตะในวัยเด็ก
# - ผู้ที่ส่งโดราเอมอนมายังอดีตคือ "เซวาชิ" เหลนของโนบิตะ
#
# **คำตอบ:**
# โดราเอมอนต้องมาช่วยเหลือโนบิตะเนื่องจากอนาคตของตระกูลโนบิจะเลวร้ายเพราะความขี้เกียจและโชคร้ายของโนบิตะในวัยเด็ก และโดราเอมอนถูกส่งมาจากโลกอนาคตโดยเซวาชิ เหลนของโนบิตะเองเพื่อเปลี่ยนแปลงอนาคตนี้ให้ดีขึ้น
#
# ==================================================
#
# Question: 8. แล้ว 'เซวาชิ' ผู้เป็นเหลนของโนบิตะ ต้องการเปลี่ยนแปลงอนาคตเรื่องใดของตระกูลโนบิ?
# จากบทความ ระบุว่า "เซวาชิ" เหลนของโนบิตะ ต้องการเปลี่ยนแปลงอนาคตอันเลวร้ายของตระกูลโนบิ ซึ่งเกิดจากความขี้เกียจและโชคร้ายของโนบิตะในวัยเด็ก
#
# **คำตอบ:**
# เซวาชิต้องการเปลี่ยนแปลงอนาคตที่เลวร้ายของตระกูลโนบิ ที่เป็นผลมาจากความขี้เกียจและโชคร้ายของโนบิตะในวัยเด็ก
#
# ==================================================
#
# Question: 9. ในการปฏิบัติภารกิจเพื่อช่วยเหลือโนบิตะที่ว่านั้น โดราเอมอนใช้สิ่งใดเป็นเครื่องมือหลัก?
# จากบทความระบุว่า โดราเอมอนใช้ "ของวิเศษจากกระเป๋าหน้าท้อง" เป็นเครื่องมือหลักในการช่วยเหลือและสั่งสอนโนบิตะให้เติบโตเป็นผู้ใหญ่ที่ดีขึ้น
#
# **คำตอบ:**
# โดราเอมอนใช้ของวิเศษจากกระเป๋าสี่มิติ (กระเป๋าหน้าท้อง) เป็นเครื่องมือหลักในการปฏิบัติภารกิจช่วยเหลือโนบิตะ
#
# ==================================================
#
# Question: 10. ความสำเร็จอย่างสูงของฉบับมังงะ ได้นำไปสู่การสร้างผลงานในรูปแบบใดต่อมา?
# จากบทความ ระบุว่า ความสำเร็จอย่างสูงของฉบับมังงะได้นำไปสู่การสร้างผลงานในรูปแบบของ **แอนิเมชัน (อะนิเมะ)** ซึ่งมีการสร้างออกมาหลายเวอร์ชัน รวมถึงภาพยนตร์จอใหญ่ในชื่อ "โดราเอมอน เดอะมูฟวี่" ที่ออกฉายอย่างต่อเนื่องเกือบทุกปี
#
# **คำตอบ:**
# ความสำเร็จของฉบับมังงะได้นำไปสู่การสร้างผลงานในรูปแบบของแอนิเมชัน (อะนิเมะ) และภาพยนตร์จอใหญ่ (โดราเอมอน เดอะมูฟวี่) ต่อมา
#
# ==================================================
#
# Question: 11. แอนิเมชันทางโทรทัศน์ที่ว่านั้น มีการสร้างครั้งแรกสุดในปี พ.ศ. ใด และออกอากาศทางสถานีใด?
# จากบทความระบุว่า แอนิเมชันทางโทรทัศน์ของโดราเอมอนชุดแรกสุดถูกสร้างขึ้นในปี พ.ศ. 2516 (ค.ศ. 1973) และออกอากาศทางสถานีโทรทัศน์นิปปอนทีวี
#
# **คำตอบ:**
# แอนิเมชันทางโทรทัศน์ของโดราเอมอนชุดแรกสุดสร้างขึ้นในปี พ.ศ. 2516 (ค.ศ. 1973) และออกอากาศทางสถานีโทรทัศน์นิปปอนทีวี
#
# ==================================================
#
# Question: 12. ซีรีส์แรกสุดในปี 2516 ที่คุณกล่าวถึง ได้รับความนิยมมากน้อยเพียงใดตามข้อมูลในบทความ?
# จากบทความระบุว่า ซีรีส์แอนิเมชันชุดแรกสุดในปี พ.ศ. 2516 (ค.ศ. 1973) ที่ออกอากาศทางสถานีโทรทัศน์นิปปอนทีวี **ไม่ได้รับความนิยมมากนักและมีจำนวนตอนไม่มากนัก**
#
# **คำตอบ:**
# ซีรีส์แรกสุดในปี พ.ศ. 2516 ที่ออกอากาศทางสถานีโทรทัศน์นิปปอนทีวี ได้รับความนิยมในระดับไม่มากนักและมีจำนวนตอนน้อย
#
# ==================================================
#
# Question: 13. หลังจากซีรีส์ชุดแรกที่ไม่ค่อยประสบความสำเร็จ ซีรีส์ชุดต่อมาที่ทำให้โดราเอมอนโด่งดังไปทั่วโลก เริ่มออกอากาศในปี พ.ศ. ใด?
# จากบทความระบุว่า ซีรีส์แอนิเมชันชุดที่ทำให้โดราเอมอนโด่งดังไปทั่วโลกนั้น เริ่มออกอากาศในปี พ.ศ. 2522 (ค.ศ. 1979) ทางสถานีโทรทัศน์ทีวีอาซาฮี
#
# **คำตอบ:**
# ซีรีส์ชุดต่อมาที่ทำให้โดราเอมอนโด่งดังไปทั่วโลก เริ่มออกอากาศในปี พ.ศ. 2522 (ค.ศ. 1979)
#
# ==================================================
#
# Question: 14. ซีรีส์ที่เริ่มฉายในปี พ.ศ. 2522 และกลายเป็นภาพจำของแฟนๆ ทั่วโลกนั้น ออกอากาศยาวนานไปจนถึงปี พ.ศ. ใด?
# จากบทความระบุว่า ซีรีส์โดราเอมอนที่เริ่มฉายในปี พ.ศ. 2522 (ค.ศ. 1979) และกลายเป็นภาพจำของแฟนๆ ทั่วโลกนั้น ออกอากาศยาวนานไปจนถึงปี พ.ศ. 2548 (ค.ศ. 2005)
#
# **คำตอบ:**
# ซีรีส์ที่เริ่มฉายในปี พ.ศ. 2522 และกลายเป็นภาพจำของแฟนๆ ทั่วโลกนั้น ออกอากาศยาวนานไปจนถึงปี พ.ศ. 2548
#
# ==================================================
#
# Question: 15. หลังจากสิ้นสุดยุคของซีรีส์ในปี 2548 ในปีถัดมาได้มีการเปลี่ยนแปลงครั้งสำคัญอะไรเกิดขึ้นกับแอนิเมชันโดราเอมอน?
# จากบทความ ระบุว่า หลังจากสิ้นสุดยุคของซีรีส์ในปี พ.ศ. 2548 ในปีถัดมา (พ.ศ. 2549 หรือ ค.ศ. 2005) ได้มีการสร้างแอนิเมชันโดราเอมอนใหม่ทั้งหมด (Reboot) โดยมีการปรับเปลี่ยนทีมงานผู้สร้าง นักพากย์ และปรับปรุงลายเส้นให้ทันสมัยยิ่งขึ้น แต่ยังคงเค้าโครงเรื่องและเสน่ห์ของตัวละครไว้อย่างครบถ้วน ซีรีส์ชุดนี้ยังคงออกอากาศต่อเนื่องมาจนถึงปัจจุบัน
#
# **คำตอบ:**
# หลังจากปี พ.ศ. 2548 ได้มีการสร้างแอนิเมชันโดราเอมอนใหม่ทั้งหมด (Reboot) โดยมีการเปลี่ยนแปลงทีมงานผู้สร้าง นักพากย์ และปรับปรุงลายเส้นให้ทันสมัยขึ้น แต่ยังคงเค้าโครงเรื่องและเสน่ห์ของตัวละครไว้อย่างครบถ้วน และซีรีส์นี้ยังออกอากาศต่อเนื่องมาจนถึงปัจจุบัน
#
# ==================================================
#
# Question: 16. การสร้างใหม่ในปี 2548 ที่ว่านั้น มีการปรับเปลี่ยนในด้านใดบ้างที่เด่นชัดตามที่บทความกล่าวไว้?
# จากบทความ ระบุว่า การสร้างใหม่ในปี พ.ศ. 2548 มีการปรับเปลี่ยนที่เด่นชัดดังนี้
#
# - ปรับเปลี่ยนทีมงานผู้สร้าง
# - ปรับเปลี่ยนนักพากย์
# - ปรับปรุงลายเส้นให้ทันสมัยยิ่งขึ้น
#
# แต่ยังคงเค้าโครงเรื่องและเสน่ห์ของตัวละครไว้อย่างครบถ้วน
#
# **คำตอบ:**
# การสร้างใหม่ในปี พ.ศ. 2548 มีการปรับเปลี่ยนทีมงานผู้สร้าง นักพากย์ และปรับปรุงลายเส้นให้ทันสมัยยิ่งขึ้น แต่ยังคงเค้าโครงเรื่องและเสน่ห์ของตัวละครไว้อย่างครบถ้วน
#
# ==================================================
#
# Question: 17. นอกเหนือจากซีรีส์ทางโทรทัศน์แล้ว โดราเอมอนยังมีผลงานในรูปแบบภาพยนตร์จอใหญ่ด้วยใช่หรือไม่? ถ้าใช่ ภาพยนตร์เรื่องแรกมีชื่อว่าอะไร?
# ใช่ค่ะ โดราเอมอนมีผลงานในรูปแบบภาพยนตร์จอใหญ่ด้วย
# ภาพยนตร์เรื่องแรกชื่อว่า **"ไดโนเสาร์ของโนบิตะ" (Nobita's Dinosaur)** ซึ่งออกฉายในปี พ.ศ. 2523 (ค.ศ. 1980) และประสบความสำเร็จอย่างงดงาม
#
# **คำตอบ:**
# โดราเอมอนมีผลงานในรูปแบบภาพยนตร์จอใหญ่ และภาพยนตร์เรื่องแรกคือ "ไดโนเสาร์ของโนบิตะ" (Nobita's Dinosaur) ออกฉายในปี พ.ศ. 2523
#
# ==================================================
#
# Question: 18. ภาพยนตร์เรื่อง 'ไดโนเสาร์ของโนบิตะ' ที่คุณเพิ่งกล่าวถึงนั้น ออกฉายในปี พ.ศ. ใด?
# ภาพยนตร์เรื่อง "ไดโนเสาร์ของโนบิตะ" (Nobita's Dinosaur) ออกฉายในปี พ.ศ. 2523 (ค.ศ. 1980)
#
# **คำตอบ:**
# ภาพยนตร์เรื่อง "ไดโนเสาร์ของโนบิตะ" ออกฉายในปี พ.ศ. 2523
#
# ==================================================
#
# Question: 19. เนื้อหาของภาพยนตร์เดอะมูฟวี่เหล่านี้ มักจะมีความแตกต่างจากฉบับทีวีซีรีส์ในลักษณะใด?
# จากบทความ ระบุว่า เนื้อหาของภาพยนตร์โดราเอมอน เดอะมูฟวี่ มักมีความแตกต่างจากฉบับทีวีซีรีส์ในลักษณะดังนี้
#
# - มีการผจญภัยในดินแดนที่แปลกใหม่และยิ่งใหญ่กว่า
# - เนื้อหาเน้นการท่องไปในอวกาศ ดำดิ่งสู่ใต้ทะเลลึก หรือย้อนกลับไปในยุคประวัติศาสตร์ต่างๆ
# - นอกจากให้ความบันเทิงแล้วยังสอดแทรกประเด็นเกี่ยวกับมิตรภาพ ความกล้าหาญ และการอนุรักษ์สิ่งแวดล้อม
#
# **คำตอบ:**
# เนื้อหาของภาพยนตร์โดราเอมอน เดอะมูฟวี่ มักแตกต่างจากฉบับทีวีซีรีส์โดยมีเนื้อหาการผจญภัยที่ยิ่งใหญ่และแปลกใหม่กว่า เช่น การท่องไปในอวกาศ ดำดิ่งสู่ใต้ทะเลลึก หรือย้อนกลับไปในยุคประวัติศาสตร์ และยังสอดแทรกประเด็นเกี่ยวกับมิตรภาพ ความกล้าหาญ และการอนุรักษ์สิ่งแวดล้อมด้วย
#
# ==================================================
#
# Question: 20. เมื่อพูดถึงความนิยมในต่างประเทศ โดยเฉพาะในประเทศไทย การ์ตูนเรื่องนี้เริ่มออกอากาศครั้งแรกเมื่อใด และผ่านทางสถานีใด?
# จากบทความ ระบุว่า การ์ตูนโดราเอมอนเริ่มออกอากาศครั้งแรกในประเทศไทยเมื่อวันที่ 5 กันยายน พ.ศ. 2525 (ค.ศ. 1982) ผ่านทางสถานีโทรทัศน์ช่อง 9 อ.ส.ม.ท. (ปัจจุบันคือ ช่อง 9 MCOT HD)
#
# **คำตอบ:**
# โดราเอมอนเริ่มออกอากาศครั้งแรกในประเทศไทยเมื่อวันที่ 5 กันยายน พ.ศ. 2525 ทางสถานีโทรทัศน์ช่อง 9 อ.ส.ม.ท. (ปัจจุบันคือ ช่อง 9 MCOT HD)
#
# ==================================================
#
# Question: 21. สถานีโทรทัศน์ช่อง 9 อ.ส.ม.ท. ที่นำโดราเอมอนมาฉายในปี 2525 นั้น ปัจจุบันคือช่องอะไร?
# จากบทความ สถานีโทรทัศน์ช่อง 9 อ.ส.ม.ท. ที่นำโดราเอมอนมาฉายในปี พ.ศ. 2525 ปัจจุบันคือ ช่อง 9 MCOT HD
#
# **คำตอบ:**
# สถานีโทรทัศน์ช่อง 9 อ.ส.ม.ท. ที่นำโดราเอมอนมาฉายในปี พ.ศ. 2525 ปัจจุบันคือ ช่อง 9 MCOT HD
#
# ==================================================
#
# Question: 22. แล้วในส่วนของฉบับหนังสือการ์ตูนในประเทศไทย ปัจจุบันสำนักพิมพ์ใดคือผู้ได้รับลิขสิทธิ์ในการจัดพิมพ์อย่างเป็นทางการ?
# จากบทความระบุว่า ปัจจุบันสำนักพิมพ์ที่ได้รับลิขสิทธิ์ในการจัดพิมพ์หนังสือการ์ตูนโดราเอมอนในประเทศไทยอย่างเป็นทางการคือ
# **สำนักพิมพ์เนชั่น เอ็ดดูเทนเมนท์**
#
# **คำตอบ:**
# ในส่วนของฉบับหนังสือการ์ตูนในประเทศไทย ปัจจุบันสำนักพิมพ์เนชั่น เอ็ดดูเทนเมนท์เป็นผู้ได้รับลิขสิทธิ์ในการจัดพิมพ์อย่างเป็นทางการ
#
# ==================================================
#
# Question: 23. นอกจากผลงานการ์ตูนแล้ว บทความได้กล่าวถึงกิจกรรมล่าสุดอะไรในไทยที่แสดงถึงความผูกพันกับแฟนๆ ?
# จากบทความกล่าวถึงกิจกรรมล่าสุดในประเทศไทยที่แสดงถึงความผูกพันกับแฟนๆ คือ
#
# - นิทรรศการ **"100% DORAEMON&FRIENDS"** ที่จัดขึ้นในปี พ.ศ. 2568
# - แอนิเมชันตอนพิเศษที่โดราเอมอนและโนบิตะเดินทางมาเที่ยวประเทศไทย โดยมีฉากหลังเป็นสถานที่ท่องเที่ยวชื่อดังอย่างอยุธยาและตลาดน้ำดำเนินสะดวก ซึ่งสร้างความประทับใจแก่แฟนๆ ชาวไทยเป็นอย่างมาก
#
# **คำตอบ:**
# กิจกรรมล่าสุดที่แสดงถึงความผูกพันกับแฟนๆ ในไทย ได้แก่ นิทรรศการ "100% DORAEMON&FRIENDS" ปี พ.ศ. 2568 และแอนิเมชันตอนพิเศษที่โดราเอมอนและโนบิตะเดินทางมาเที่ยวประเทศไทย มีฉากหลังเป็นสถานที่ท่องเที่ยวชื่อดัง เช่น อยุธยา และตลาดน้ำดำเนินสะดวก
#
# ==================================================
#
# Question: 24. นอกเหนือจากนิทรรศการ '100% DORAEMON&FRIENDS' แล้ว ยังมีผลงานแอนิเมชันตอนพิเศษอะไรอีกที่สร้างขึ้นเพื่อแฟนชาวไทยโดยเฉพาะ?
# จากบทความ นอกจากนิทรรศการ "100% DORAEMON&FRIENDS" แล้ว ยังมีผลงานแอนิเมชันตอนพิเศษที่โดราเอมอนและโนบิตะเดินทางมาเที่ยวประเทศไทย โดยมีฉากหลังเป็นสถานที่ท่องเที่ยวชื่อดังอย่างอยุธยาและตลาดน้ำดำเนินสะดวก ซึ่งสร้างความประทับใจแก่แฟนๆ ชาวไทยเป็นอย่างมาก
#
# **คำตอบ:**
# นอกจากนิทรรศการ "100% DORAEMON&FRIENDS" แล้ว ยังมีแอนิเมชันตอนพิเศษที่โดราเอมอนและโนบิตะเดินทางมาเที่ยวประเทศไทย โดยมีฉากหลังเป็นสถานที่ท่องเที่ยวชื่อดัง เช่น อยุธยา และตลาดน้ำดำเนินสะดวก ซึ่งสร้างความประทับใจให้กับแฟนชาวไทยโดยเฉพาะ
#
# ==================================================
#
# Question: 25. ในตอนพิเศษที่โดราเอมอนและโนบิตะมาเที่ยวประเทศไทยนั้น พวกเขาได้เดินทางไปยังสถานที่ท่องเที่ยวสำคัญแห่งใดบ้าง?
# จากบทความระบุว่า ในแอนิเมชันตอนพิเศษที่โดราเอมอนและโนบิตะเดินทางมาเที่ยวประเทศไทยนั้น พวกเขาได้เดินทางไปยังสถานที่ท่องเที่ยวสำคัญ ได้แก่
#
# - อยุธยา
# - ตลาดน้ำดำเนินสะดวก
#
# **คำตอบ:**
# ในตอนพิเศษที่โดราเอมอนและโนบิตะมาเที่ยวประเทศไทย พวกเขาได้เดินทางไปยังสถานที่ท่องเที่ยวสำคัญอย่างอยุธยาและตลาดน้ำดำเนินสะดวก
#
# ==================================================
#
# Question: 26. ความนิยมในระดับนานาชาติของโดราเอมอน ทำให้ได้รับการแต่งตั้งให้ดำรงตำแหน่งสำคัญอะไรจากรัฐบาลญี่ปุ่น?
# จากบทความระบุว่า ความนิยมในระดับนานาชาติของโดราเอมอน ทำให้ได้รับการแต่งตั้งให้ดำรงตำแหน่งเป็น
# **"ทูตวัฒนธรรมแอนิเมชัน" คนแรกของประเทศญี่ปุ่น** ในปี พ.ศ. 2551 (ค.ศ. 2008)
#
# **คำตอบ:**
# โดราเอมอนได้รับการแต่งตั้งให้เป็น "ทูตวัฒนธรรมแอนิเมชัน" คนแรกของญี่ปุ่น จากรัฐบาลญี่ปุ่นในปี พ.ศ. 2551
#
# ==================================================
#
# Question: 27. การได้รับตำแหน่ง 'ทูตวัฒนธรรมแอนิเมชัน' คนแรกที่ว่านั้น เกิดขึ้นในปี พ.ศ. ใด?
# จากบทความ ระบุว่า โดราเอมอนได้รับการแต่งตั้งให้เป็น "ทูตวัฒนธรรมแอนิเมชัน" คนแรกของญี่ปุ่นในปี พ.ศ. 2551 (ค.ศ. 2008)
#
# **คำตอบ:**
# การได้รับตำแหน่ง "ทูตวัฒนธรรมแอนิเมชัน" คนแรกนั้น เกิดขึ้นในปี พ.ศ. 2551
#
# ==================================================
#
# Question: 28. จากที่เราคุยกันมาทั้งหมด ตั้งแต่จุดกำเนิดในรูปแบบมังงะจนถึงการเป็นทูตวัฒนธรรม คุณคิดว่าแอนิเมชันซีรีส์ในยุคใด (พ.ศ.) ที่บทความระบุว่ามีบทบาทสำคัญที่สุดในการสร้างชื่อเสียงระดับโลกให้กับโดราเอมอน?
# จากบทความ ระบุว่า แอนิเมชันซีรีส์ในยุค พ.ศ. 2522 - 2548 (ค.ศ. 1979 - 2005) เป็นเวอร์ชันที่สร้างชื่อเสียงและทำให้โดราเอมอนเป็นที่รู้จักไปทั่วโลก ด้วยจำนวนตอนกว่า 1,787 ตอน และลายเส้นที่กลายเป็นภาพจำของแฟนๆ ทั่วโลก รวมถึงในประเทศไทย
#
# **คำตอบ:**
# แอนิเมชันซีรีส์ในยุค พ.ศ. 2522 - 2548 มีบทบาทสำคัญที่สุดในการสร้างชื่อเสียงระดับโลกให้กับโดราเอมอน
#
# ==================================================
#
# Question: 29. เมื่อพิจารณาจากแอนิเมะยุคที่โด่งดังที่สุด (พ.ศ. 2522-2548) และภาพยนตร์เรื่องแรก (พ.ศ. 2523) เหตุการณ์ใดเกิดขึ้นก่อนกัน?
# จากบทความระบุว่า
# - แอนิเมะซีรีส์ยุคที่โด่งดังที่สุด เริ่มออกอากาศในปี พ.ศ. 2522 (ค.ศ. 1979)
# - ภาพยนตร์เรื่องแรก "ไดโนเสาร์ของโนบิตะ" ออกฉายในปี พ.ศ. 2523 (ค.ศ. 1980)
#
# ดังนั้นเหตุการณ์ที่เกิดขึ้นก่อนคือ
# **การออกอากาศแอนิเมะซีรีส์ยุคที่โด่งดังที่สุดในปี พ.ศ. 2522** ก่อนภาพยนตร์เรื่องแรกในปี พ.ศ. 2523
#
# **คำตอบ:**
# แอนิเมะซีรีส์ยุค พ.ศ. 2522-2548 เริ่มออกอากาศก่อนภาพยนตร์เรื่องแรก "ไดโนเสาร์ของโนบิตะ" ที่ออกฉายในปี พ.ศ. 2523
#
# ==================================================
#
# Question: 30. สุดท้ายแล้ว จากการเดินทางอันยาวนานที่เริ่มต้นจากปลายปากกาของ 'ฟูจิโกะ เอฟ ฟูจิโอะ' บทความได้สรุปว่าโดราเอมอนได้มอบมรดกที่สำคัญอะไรให้กับผู้คนทั่วโลก?
# จากบทความสรุปไว้ว่า โดราเอมอนได้มอบมรดกที่สำคัญให้กับผู้คนทั่วโลกคือ
#
# - จินตนาการและมิตรภาพเป็นภาษาสากลที่สามารถก้าวข้ามผ่านพรมแดนและกาลเวลา
# - จากจุดเริ่มต้นในหน้ากระดาษเมื่อกว่า 50 ปีที่ผ่านมา สู่การเป็นไอคอนทางวัฒนธรรม
# - ยังคงมอบความสุข เสียงหัวเราะ และแรงบันดาลใจให้กับผู้คนทั่วโลกอย่างต่อเนื่อง
#
# **คำตอบ:**
# โดราเอมอนมอบมรดกที่สำคัญคือ จินตนาการและมิตรภาพซึ่งเป็นภาษาสากลที่ก้าวข้ามพรมแดนและกาลเวลา และกลายเป็นไอคอนทางวัฒนธรรมที่ให้ความสุข เสียงหัวเราะ และแรงบันดาลใจแก่ผู้คนทั่วโลกตลอดมา
#
# ==================================================
